# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.chdir('/content/drive/MyDrive/Chatbot/classifier_model/')

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("emotion-emotion_69k - emotion-emotion_69k.csv")

# %%
#print first 5 rows
df.head(2)
# Out:
#    Unnamed: 0                                          Situation      emotion  \
# 0           0  I remember going to the fireworks with my best...  sentimental
# 1           1  I remember going to the fireworks with my best...  sentimental
#
#                                 empathetic_dialogues  \
# 0  Customer :I remember going to see the firework...
# 1  Customer :This was a best friend. I miss her.\...
#
#                                               labels Unnamed: 5 Unnamed: 6
# 0  Was this a friend you were in love with, or ju...        NaN        NaN
# 1                                Where has she gone?        NaN        NaN

# %%
#print the shape of the data set
print(df.shape)
# Out:
# (64636, 7)

# %%
df = df[['Situation', 'emotion']]

# %%
df.isnull().sum()
# Out:
# Situation    0
# emotion      5
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Situation    0
# emotion      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 45333

# %%
df = df.drop_duplicates()

# %%
#check if the data is balanced or not
df.emotion.value_counts()
# Out:
# emotion
# surprised       1000
# excited          741
# angry            686
# proud            669
# sad              663
# annoyed          662
# grateful         638
# lonely           633
# afraid           626
# impressed        617
# terrified        617
# hopeful          616
# guilty           613
# disgusted        613
# anxious          612
# confident        611
# furious          599
# anticipating     598
# joyful           598
# nostalgic        596
# disappointed     595
# prepared         589
# jealous          579
# content          570
# embarrassed      558
# devastated       557
# sentimental      515
# caring           503
# trusting         499
# ashamed          490
# apprehensive     463
# faithful         372
# Name: count, dtype: int64

# %% [markdown]
# ### Text Preprocessing

# %%
df.head()
# Out:
#                                             Situation      emotion
# 0   I remember going to the fireworks with my best...  sentimental
# 5                        i used to scare for darkness       afraid
# 10  I showed a guy how to run a good bead in weldi...        proud
# 14               I have always been loyal to my wife.     faithful
# 17  A recent job interview that I had made me feel...    terrified

# %%
df.reset_index(drop=True, inplace = True)

# %%
df.shape
# Out:
# (19298, 2)

# %%
df.head()
# Out:
#                                            Situation      emotion
# 0  I remember going to the fireworks with my best...  sentimental
# 1                       i used to scare for darkness       afraid
# 2  I showed a guy how to run a good bead in weldi...        proud
# 3               I have always been loyal to my wife.     faithful
# 4  A recent job interview that I had made me feel...    terrified

# %%
import gensim
import string
import spacy

# %%
nlp = spacy.load("en_core_web_sm")
stop_words = nlp.Defaults.stop_words
print(stop_words)
# Out:
# {'’re', "'s", 'keep', 'over', 'everything', 'besides', 'or', 'us', 'seem', 'himself', 'therein', 'eight', 'my', 'somewhere', 'former', 'whenever', 'last', 'whence', 'may', 'before', 'ca', 'doing', 'hereupon', 'becomes', 'how', 're', 'behind', 'can', 'meanwhile', 'name', 'neither', 'although', 'serious', 'anyone', 'anywhere', 'about', 'she', 'anything', 'with', 'latterly', 'front', 'wherever', 'their', 'every', 'do', 'other', 'many', 'thereupon', 'as', 'whereby', 'always', 'against', 'he', 'by', 'indeed', 'same', 'move', 'them', 'whatever', 'hereafter', 'amongst', 'get', 'seems', 'under', 'a', 'be', 'am', 'without', 'it', 'anyhow', 'thereby', 'when', 'go', 'three', 'cannot', 'each', 'mostly', 'on', 'twenty', 'does', 'they', 'will', '‘s', 'and', 'yourself', 'whose', 'thru', 'fifty', 'because', 'across', 'first', 'next', 'beside', 'amount', 'thence', 'herself', 'did', 'even', 'nor', 'n’t', 'should', 'why', 'since', 'now', 'various', 'upon', 'our', 'whither', 'namely', '‘ve', 'sometime', 'there', 'him', 'twelve', 'where', 'hundred', 'some', 'between', 'towards', 'me', 'beyond', 'yourselves', 'elsewhere', 'rather', 'below', 'all', 'any', 'here', '‘d', 'had', 'few', 'well', 'what', '’s', 'once', 'almost', 'in', 'two', 'than', 'your', 'therefore', 'everyone', 'n‘t', 'were', "'re", 'her', 'take', 'several', 'unless', 'more', 'down', '‘re', 'somehow', 'four', 'latter', 'ours', 'one', 'made', 'nevertheless', 'bottom', 'i', 'up', 'eleven', 'much', 'was', 'also', 'nothing', 'whether', 'the', 'his', 'above', 'none', "'ll", 'really', 'whom', 'through', 'been', 'is', 'toward', 'very', 'off', 'sixty', 'afterwards', 'who', 'call', 'most', 'whereas', 'thereafter', 'via', 'yet', 'anyway', 'at', 'of', 'while', 'forty', 'such', 'too', 'enough', 'not', 'being', 'so', 'wherein', 'from', 'might', 'this', 'five', 'formerly', 'ourselves', 'only', 'otherwise', "'ve", '’ve', 'further', 'give', '‘ll', 'however', 'that', 'never', 'myself', 'done', 'else', 'side', 'become', 'thus', 'have', '’d', 'nine', 'both', 'whereafter', 'mine', 'into', 'due', "'d", 'to', 'must', 'along', 'top', 'throughout', 'something', 'part', 'has', 'someone', 'using', 'no', 'around', 'could', '‘m', '’ll', 'six', 'if', 'regarding', 'again', 'own', 'empty', 'nobody', 'noone', 'often', 'seemed', 'we', 'see', 'themselves', 'are', 'becoming', 'onto', 'beforehand', 'ever', 'after', 'hers', 'fifteen', 'still', 'you', "n't", 'just', 'make', 'though', 'quite', 'during', 'please', 'alone', 'least', 'hereby', 'these', 'another', 'used', 'say', 'third', 'ten', 'perhaps', 'for', 'per', '’m', "'m", 'others', 'sometimes', 'those', 'its', 'nowhere', 'yours', 'but', 'seeming', 'herein', 'within', 'everywhere', 'whole', 'put', 'an', 'already', 'whereupon', 'would', 'except', 'itself', 'which', 'show', 'less', 'back', 'out', 'among', 'until', 'hence', 'full', 'became', 'moreover', 'whoever', 'together', 'either', 'then'}

# %%
punctuations = string.punctuation
print(punctuations)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Creating our tokenizer function

def spacy_tokenizer(sentence):

    # Creating our token object, which is used to create documents with linguistic annotations.
    doc = nlp(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() for word in doc ]

    # print(mytokens)

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens

# %%
import gensim.downloader as api
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wv.save('word2vec-google-news-300.kv')

# %%
def sent_vec(sent):
    vector_size = wv.vector_size
    wv_res = np.zeros(vector_size)
    # print(wv_res)
    ctr = 1
    for w in sent:
        if w in wv:
            ctr += 1
            wv_res += wv[w]
    wv_res = wv_res/ctr
    return wv_res

# %%
df['tokens'] = df['Situation'].apply(spacy_tokenizer)

# %%
df.head(2)
# Out:
#                                            Situation  emotion  \
# 0  I remember going to the fireworks with my best...       26
# 1                       i used to scare for darkness        8
#
#                                               tokens
# 0  [remember, firework, good, friend, lot, people...
# 1                             [use, scare, darkness]

# %%
df['vec'] = df['tokens'].apply(sent_vec)

# %%
df.head(2)

# %%
df['emotion'].unique()
# Out:
# array(['sentimental', 'afraid', 'proud', 'faithful', 'terrified',
#        'joyful', 'angry', 'sad', 'jealous', 'grateful', 'prepared',
#        'embarrassed', 'excited', 'annoyed', 'lonely', 'ashamed', 'guilty',
#        'surprised', 'nostalgic', 'confident', 'furious', 'disappointed',
#        'caring', 'trusting', 'disgusted', 'anticipating', 'anxious',
#        'hopeful', 'content', 'impressed', 'apprehensive', 'devastated'],
#       dtype=object)

# %%
df['emotion'].nunique()
# Out:
# 32

# %%
emotion_replacements = {
    'surprised': 0,'excited': 1,'angry':2,'proud':3,'sad':4,'annoyed':5,'grateful':6,'lonely':7,'afraid':8,'hopeful':9,
    'terrified':10,'anxious':11,'guilty':12,'impressed':13,'disgusted':14,'confident':15,'anticipating':16,'joyful':17,
    'nostalgic':18,'furious':19,'disappointed':20,'prepared':21,'jealous':22,'content':23,'embarrassed':24,'devastated':25,
    'sentimental':26,'caring':27,'trusting':28,'ashamed':29,'apprehensive':30,'faithful':31}

# Replace emotions using the dictionary
df['emotion'] = df['emotion'].replace(emotion_replacements)

# %%
df['emotion'].unique()
# Out:
# array([26,  8,  3, 31, 10, 17,  2,  4, 22,  6, 21, 24,  1,  5,  7, 29, 12,
#         0, 18, 15, 19, 20, 27, 28, 14, 16, 11,  9, 23, 13, 30, 25])

# %%
# Splitting the data into independent and dependent

x = df['vec'].to_list()
y = df['emotion'].to_list()

# %%
# Check the indices
print(df.index)
# Out:
# RangeIndex(start=0, stop=19298, step=1)

# %%
from imblearn.over_sampling import SMOTE,RandomOverSampler
resampled_X,resampled_Y=RandomOverSampler().fit_resample(x, y)

# %%
resampled_X
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
resampled_Y
# Out:
# [26,
#  8,
#  3,
#  31,
#  10,
#  17,
#  2,
#  4,
#  22,
#  6,
#  4,
#  21,
#  24,
#  2,
#  8,
#  1,
#  5,
#  2,
#  7,
#  3,
#  26,
#  17,
#  29,
#  12,
#  0,
#  18,
#  15,
#  5,
#  12,
#  19,
#  12,
#  10,
#  19,
#  20,
#  31,
#  27,
#  4,
#  20,
#  6,
#  26,
#  1,
#  1,
#  27,
#  8,
#  5,
#  28,
#  12,
#  14,
#  19,
#  2,
#  4,
#  16,
#  11,
#  18,
#  0,
#  3,
#  4,
#  17,
#  8,
#  2,
#  11,
#  14,
#  9,
#  26,
#  19,
#  22,
#  15,
#  23,
#  3,
#  13,
#  19,
#  21,
#  28,
#  8,
#  0,
#  1,
#  19,
#  11,
#  2,
#  20,
#  1,
#  24,
#  10,
#  9,
#  9,
#  5,
#  27,
#  5,
#  19,
#  8,
#  9,
#  21,
#  6,
#  10,
#  1,
#  29,
#  30,
#  0,
#  12,
#  7,
#  7,
#  14,
#  4,
#  3,
#  19,
#  29,
#  15,
#  4,
#  12,
#  14,
#  5,
#  11,
#  0,
#  20,
#  8,
#  18,
#  6,
#  25,
#  17,
#  21,
#  13,
#  4,
#  31,
#  8,
#  7,
#  12,
#  4,
#  11,
#  15,
#  8,
#  3,
#  6,
#  16,
#  9,
#  4,
#  0,
#  4,
#  31,
#  22,
#  4,
#  17,
#  9,
#  1,
#  27,
#  7,
#  24,
#  16,
#  18,
#  0,
#  3,
#  0,
#  10,
#  22,
#  27,
#  26,
#  19,
#  18,
#  8,
#  8,
#  3,
#  4,
#  27,
#  4,
#  1,
#  1,
#  8,
#  13,
#  13,
#  7,
#  8,
#  21,
#  4,
#  8,
#  13,
#  0,
#  5,
#  8,
#  10,
#  0,
#  29,
#  26,
#  6,
#  24,
#  10,
#  21,
#  6,
#  2,
#  9,
#  5,
#  17,
#  11,
#  15,
#  3,
#  0,
#  15,
#  9,
#  28,
#  12,
#  29,
#  1,
#  26,
#  19,
#  14,
#  24,
#  6,
#  24,
#  9,
#  18,
#  27,
#  20,
#  17,
#  23,
#  21,
#  1,
#  20,
#  18,
#  11,
#  22,
#  3,
#  0,
#  8,
#  2,
#  22,
#  21,
#  1,
#  25,
#  1,
#  30,
#  25,
#  23,
#  11,
#  8,
#  1,
#  6,
#  6,
#  30,
#  22,
#  7,
#  18,
#  22,
#  13,
#  3,
#  16,
#  12,
#  17,
#  11,
#  2,
#  23,
#  1,
#  13,
#  0,
#  10,
#  19,
#  4,
#  15,
#  5,
#  10,
#  12,
#  8,
#  27,
#  13,
#  4,
#  3,
#  17,
#  8,
#  5,
#  31,
#  15,
#  8,
#  16,
#  25,
#  24,
#  0,
#  7,
#  24,
#  10,
#  25,
#  14,
#  0,
#  3,
#  0,
#  12,
#  25,
#  22,
#  21,
#  20,
#  10,
#  10,
#  9,
#  17,
#  2,
#  30,
#  22,
#  15,
#  12,
#  0,
#  0,
#  31,
#  13,
#  0,
#  3,
#  3,
#  0,
#  18,
#  4,
#  31,
#  3,
#  31,
#  17,
#  30,
#  5,
#  20,
#  10,
#  12,
#  15,
#  0,
#  0,
#  6,
#  15,
#  12,
#  6,
#  2,
#  1,
#  7,
#  3,
#  18,
#  19,
#  10,
#  15,
#  9,
#  17,
#  27,
#  1,
#  20,
#  7,
#  10,
#  15,
#  17,
#  9,
#  15,
#  22,
#  17,
#  19,
#  9,
#  5,
#  15,
#  16,
#  6,
#  7,
#  1,
#  8,
#  13,
#  5,
#  22,
#  1,
#  14,
#  24,
#  20,
#  7,
#  1,
#  30,
#  9,
#  10,
#  3,
#  21,
#  25,
#  5,
#  7,
#  0,
#  21,
#  16,
#  19,
#  18,
#  14,
#  2,
#  13,
#  21,
#  9,
#  5,
#  20,
#  12,
#  4,
#  28,
#  8,
#  18,
#  6,
#  4,
#  1,
#  10,
#  25,
#  17,
#  17,
#  4,
#  13,
#  20,
#  8,
#  24,
#  15,
#  25,
#  10,
#  0,
#  10,
#  29,
#  9,
#  30,
#  0,
#  4,
#  18,
#  1,
#  12,
#  8,
#  20,
#  1,
#  24,
#  9,
#  1,
#  11,
#  9,
#  20,
#  27,
#  7,
#  25,
#  29,
#  3,
#  11,
#  24,
#  14,
#  6,
#  22,
#  2,
#  21,
#  18,
#  30,
#  19,
#  0,
#  0,
#  25,
#  26,
#  8,
#  0,
#  22,
#  0,
#  2,
#  22,
#  4,
#  29,
#  14,
#  31,
#  5,
#  20,
#  15,
#  12,
#  3,
#  18,
#  16,
#  15,
#  22,
#  21,
#  31,
#  13,
#  21,
#  2,
#  0,
#  22,
#  27,
#  22,
#  1,
#  8,
#  15,
#  1,
#  6,
#  0,
#  29,
#  7,
#  2,
#  22,
#  24,
#  10,
#  4,
#  3,
#  14,
#  3,
#  26,
#  24,
#  3,
#  4,
#  1,
#  6,
#  22,
#  9,
#  4,
#  5,
#  23,
#  13,
#  13,
#  26,
#  4,
#  10,
#  12,
#  5,
#  0,
#  2,
#  24,
#  14,
#  6,
#  17,
#  0,
#  29,
#  10,
#  11,
#  28,
#  30,
#  14,
#  12,
#  1,
#  11,
#  29,
#  4,
#  13,
#  8,
#  21,
#  4,
#  15,
#  0,
#  10,
#  12,
#  3,
#  0,
#  4,
#  11,
#  17,
#  18,
#  8,
#  28,
#  17,
#  14,
#  27,
#  16,
#  26,
#  9,
#  2,
#  16,
#  2,
#  15,
#  17,
#  12,
#  8,
#  4,
#  31,
#  12,
#  0,
#  6,
#  17,
#  27,
#  23,
#  12,
#  2,
#  18,
#  24,
#  10,
#  16,
#  12,
#  2,
#  6,
#  26,
#  18,
#  5,
#  16,
#  22,
#  11,
#  25,
#  30,
#  18,
#  9,
#  12,
#  0,
#  22,
#  22,
#  1,
#  7,
#  26,
#  13,
#  12,
#  21,
#  1,
#  13,
#  27,
#  6,
#  0,
#  2,
#  1,
#  25,
#  19,
#  10,
#  23,
#  2,
#  1,
#  20,
#  6,
#  1,
#  22,
#  5,
#  25,
#  14,
#  1,
#  1,
#  2,
#  17,
#  11,
#  0,
#  11,
#  20,
#  24,
#  11,
#  17,
#  31,
#  29,
#  0,
#  18,
#  8,
#  0,
#  27,
#  15,
#  21,
#  5,
#  7,
#  13,
#  0,
#  7,
#  3,
#  11,
#  0,
#  7,
#  2,
#  12,
#  24,
#  18,
#  5,
#  14,
#  3,
#  19,
#  29,
#  30,
#  17,
#  30,
#  6,
#  4,
#  0,
#  26,
#  18,
#  28,
#  4,
#  11,
#  1,
#  12,
#  25,
#  16,
#  23,
#  25,
#  23,
#  13,
#  25,
#  7,
#  8,
#  16,
#  0,
#  31,
#  5,
#  9,
#  4,
#  31,
#  2,
#  26,
#  30,
#  4,
#  20,
#  18,
#  16,
#  15,
#  18,
#  7,
#  3,
#  18,
#  16,
#  9,
#  20,
#  17,
#  23,
#  29,
#  3,
#  0,
#  11,
#  9,
#  4,
#  4,
#  3,
#  19,
#  20,
#  28,
#  16,
#  11,
#  2,
#  2,
#  27,
#  8,
#  26,
#  8,
#  14,
#  7,
#  16,
#  23,
#  0,
#  20,
#  20,
#  17,
#  19,
#  3,
#  28,
#  0,
#  11,
#  0,
#  21,
#  15,
#  1,
#  17,
#  12,
#  1,
#  9,
#  1,
#  6,
#  3,
#  12,
#  16,
#  5,
#  20,
#  1,
#  0,
#  17,
#  2,
#  22,
#  9,
#  9,
#  3,
#  17,
#  12,
#  11,
#  28,
#  4,
#  10,
#  18,
#  29,
#  13,
#  0,
#  7,
#  6,
#  10,
#  10,
#  1,
#  21,
#  1,
#  12,
#  4,
#  1,
#  11,
#  12,
#  20,
#  31,
#  18,
#  3,
#  10,
#  13,
#  0,
#  0,
#  28,
#  6,
#  11,
#  22,
#  22,
#  31,
#  25,
#  28,
#  3,
#  24,
#  16,
#  8,
#  21,
#  27,
#  3,
#  30,
#  21,
#  0,
#  10,
#  8,
#  1,
#  0,
#  10,
#  10,
#  21,
#  10,
#  3,
#  19,
#  1,
#  8,
#  1,
#  27,
#  8,
#  8,
#  28,
#  7,
#  19,
#  7,
#  3,
#  31,
#  15,
#  2,
#  17,
#  12,
#  8,
#  19,
#  0,
#  8,
#  13,
#  2,
#  27,
#  0,
#  5,
#  11,
#  12,
#  8,
#  11,
#  7,
#  22,
#  22,
#  27,
#  1,
#  12,
#  0,
#  24,
#  17,
#  3,
#  8,
#  31,
#  20,
#  21,
#  2,
#  24,
#  2,
#  13,
#  3,
#  1,
#  14,
#  22,
#  28,
#  23,
#  5,
#  1,
#  13,
#  30,
#  26,
#  11,
#  7,
#  2,
#  19,
#  14,
#  0,
#  21,
#  11,
#  15,
#  5,
#  8,
#  10,
#  6,
#  19,
#  8,
#  27,
#  23,
#  18,
#  5,
#  22,
#  22,
#  17,
#  19,
#  24,
#  26,
#  17,
#  6,
#  11,
#  0,
#  23,
#  21,
#  5,
#  12,
#  28,
#  13,
#  18,
#  19,
#  8,
#  21,
#  10,
#  6,
#  13,
#  22,
#  24,
#  24,
#  20,
#  28,
#  6,
#  11,
#  10,
#  1,
#  4,
#  9,
#  3,
#  1,
#  23,
#  18,
#  28,
#  8,
#  14,
#  23,
#  21,
#  26,
#  29,
#  15,
#  16,
#  24,
#  18,
#  12,
#  2,
#  26,
#  6,
#  4,
#  27,
#  17,
#  11,
#  0,
#  2,
#  19,
#  0,
#  13,
#  2,
#  4,
#  25,
#  29,
#  5,
#  16,
#  12,
#  9,
#  5,
#  16,
#  3,
#  12,
#  26,
#  23,
#  8,
#  14,
#  20,
#  4,
#  1,
#  14,
#  27,
#  7,
#  10,
#  0,
#  19,
#  11,
#  2,
#  20,
#  28,
#  16,
#  4,
#  16,
#  22,
#  17,
#  21,
#  24,
#  13,
#  30,
#  30,
#  22,
#  23,
#  7,
#  25,
#  9,
#  12,
#  25,
#  14,
#  25,
#  0,
#  18,
#  31,
#  21,
#  11,
#  22,
#  19,
#  3,
#  5,
#  8,
#  6,
#  16,
#  ...]

# %%
# Train-test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(resampled_X, resampled_Y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier()

# %%
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
Accuracy = accuracy_score(y_test, y_pred)
print(Accuracy)
# Out:
# 0.7171875

# %%
Precision = precision_score(y_test, y_pred, average = 'weighted')
print(Precision)
# Out:
# 0.7198883202541586

# %%
Recall = recall_score(y_test, y_pred, average = 'micro')
print(Recall)
# Out:
# 0.7171875

# %%
F1 = f1_score(y_test, y_pred, average = 'macro')
print(F1)
# Out:
# 0.7155128924232221
